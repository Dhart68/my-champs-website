# %%
import requests
import pandas as pd


# Get the list of games from the scoreboard
scoreboard_url = f"https://cdn.nba.com/static/json/liveData/scoreboard/todaysScoreboard_00.json"
games = requests.get(scoreboard_url).json()["scoreboard"]["games"]

# %%
from nba_api.stats.endpoints import playbyplayv3

# %%
from nba_api.stats.endpoints import ScheduleLeagueV2

# %%
schedule = ScheduleLeagueV2()
schedule

# %%
schedule_nba = schedule.get_data_frames()[0]

# %%
schedule_nba.columns
# Out:
# Index(['leagueId', 'seasonYear', 'gameDate', 'gameId', 'gameCode',
#        'gameStatus', 'gameStatusText', 'gameSequence', 'gameDateEst',
#        'gameTimeEst',
#        ...
#        'awayOttBroadcasters_broadcasterMedia',
#        'awayOttBroadcasters_broadcasterId',
#        'awayOttBroadcasters_broadcasterDisplay',
#        'awayOttBroadcasters_broadcasterAbbreviation',
#        'awayOttBroadcasters_broadcasterDescription',
#        'awayOttBroadcasters_tapeDelayComments',
#        'awayOttBroadcasters_broadcasterVideoLink',
#        'awayOttBroadcasters_broadcasterTeamId',
#        'awayOttBroadcasters_broadcasterRanking',
#        'awayOttBroadcasters_localizationRegion'],
#       dtype='object', length=173)

# %%
## trouver le temps du moment la veille des match

## chercher dans le schedule les match prevu et trouver les heures des matchs

## faire un test si donnees dispo a la fin de match theorique + 5minutes puis +10 minutes etc...

## lancer les upload des matchs finis

## attendre la fin du dernier match et de son download pour declencher l'update de l'app



schedule_nba.head()
# Out:
#   leagueId seasonYear             gameDate      gameId         gameCode  \
# 0       00    2025-26  10/02/2025 00:00:00  0012500008  20251002/PHINYK
# 1       00    2025-26  10/03/2025 00:00:00  0012500001  20251003/PHXLAL
# 2       00    2025-26  10/03/2025 00:00:00  0012500009  20251003/MELNOP
# 3       00    2025-26  10/04/2025 00:00:00  0012500010  20251004/NYKPHI
# 4       00    2025-26  10/04/2025 00:00:00  0012500011  20251004/SEMNOP
#
#    gameStatus        gameStatusText  gameSequence           gameDateEst  \
# 0           3                 Final             1  2025-10-02T00:00:00Z
# 1           3                 Final             2  2025-10-03T00:00:00Z
# 2           3  Final                            1  2025-10-03T00:00:00Z
# 3           3                 Final             1  2025-10-04T00:00:00Z
# 4           3  Final                            5  2025-10-04T00:00:00Z
#
#             gameTimeEst  ... awayOttBroadcasters_broadcasterMedia  \
# 0  1900-01-01T12:00:00Z  ...                                 None
# 1  1900-01-01T22:00:00Z  ...                                  ott
# 2  1900-01-01T05:30:00Z  ...                                 None
# 3  1900-01-01T11:00:00Z  ...                                 None
# 4  1900-01-01T23:00:00Z  ...                                 None
#
#   awayOttBroadcasters_broadcasterId awayOttBroadcasters_broadcasterDisplay  \
# 0                               NaN                                   None
# 1                         1001033.0                                  Suns+
# 2                               NaN                                   None
# 3                               NaN                                   None
# 4                               NaN                                   None
#
#   awayOttBroadcasters_broadcasterAbbreviation  \
# 0                                        None
# 1                                     DTC-PHX
# 2                                        None
# 3                                        None
# 4                                        None
#
#   awayOttBroadcasters_broadcasterDescription  \
# 0                                       None
# 1
# 2                                       None
# 3                                       None
# 4                                       None
#
#   awayOttBroadcasters_tapeDelayComments  \
# 0                                  None
# 1
# 2                                  None
# 3                                  None
# 4                                  None
#
#   awayOttBroadcasters_broadcasterVideoLink  \
# 0                                     None
# 1
# 2                                     None
# 3                                     None
# 4                                     None
#
#    awayOttBroadcasters_broadcasterTeamId  \
# 0                                    NaN
# 1                           1.610613e+09
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    awayOttBroadcasters_broadcasterRanking  \
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
#
#   awayOttBroadcasters_localizationRegion
# 0                                   None
# 1
# 2                                   None
# 3                                   None
# 4                                   None
#
# [5 rows x 173 columns]

# %%
from datetime import datetime
today = datetime.today().strftime("%Y-%m-%d")
today
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[155], line 2
#       1 from datetime import datetime
# ----> 2 today = datetime.today('utc').strftime("%Y-%m-%d")
#       3 today
#
# TypeError: datetime.today() takes no arguments (1 given)

# %%
schedule_day = schedule_nba[schedule_nba['gameDateEst'].str[:10] == today]

# %%
pd.reset_option('display.max_columns')

# %%
schedule_nba[schedule_nba['homeTeam_teamName']=="Warriors"]
# Out:
#      leagueId seasonYear             gameDate      gameId         gameCode  \
# 9          00    2025-26  10/05/2025 00:00:00  0012500030  20251005/LALGSW
# 19         00    2025-26  10/08/2025 00:00:00  0012500015  20251008/PORGSW
# 69         00    2025-26  10/17/2025 00:00:00  0012500069  20251017/LACGSW
# 86         00    2025-26  10/23/2025 00:00:00  0022500006  20251023/DENGSW
# 122        00    2025-26  10/27/2025 00:00:00  0022500121  20251027/MEMGSW
# 128        00    2025-26  10/28/2025 00:00:00  0022500127  20251028/LACGSW
# 178        00    2025-26  11/04/2025 00:00:00  0022500169  20251104/PHXGSW
# 216        00    2025-26  11/09/2025 00:00:00  0022500196  20251109/INDGSW
# 305        00    2025-26  11/21/2025 00:00:00  0022500056  20251121/PORGSW
# 329        00    2025-26  11/24/2025 00:00:00  0022500291  20251124/UTAGSW
# 340        00    2025-26  11/26/2025 00:00:00  0022500066  20251126/HOUGSW
# 359        00    2025-26  11/29/2025 00:00:00  0022500298  20251129/NOPGSW
# 384        00    2025-26  12/02/2025 00:00:00  0022500323  20251202/OKCGSW
# 460        00    2025-26  12/20/2025 00:00:00  0022500392  20251220/PHXGSW
# 475        00    2025-26  12/22/2025 00:00:00  0022500407  20251222/ORLGSW
# 493        00    2025-26  12/25/2025 00:00:00  0022500011  20251225/DALGSW
# 557        00    2025-26  01/02/2026 00:00:00  0022500484  20260102/OKCGSW
# 565        00    2025-26  01/03/2026 00:00:00  0022500492  20260103/UTAGSW
# 599        00    2025-26  01/07/2026 00:00:00  0022500526  20260107/MILGSW
# 612        00    2025-26  01/09/2026 00:00:00  0022500539  20260109/SACGSW
# 629        00    2025-26  01/11/2026 00:00:00  0022500556  20260111/ATLGSW
# 643        00    2025-26  01/13/2026 00:00:00  0022500570  20260113/PORGSW
# 657        00    2025-26  01/15/2026 00:00:00  0022500584  20260115/NYKGSW
# 672        00    2025-26  01/17/2026 00:00:00  0022500599  20260117/CHAGSW
# 689        00    2025-26  01/19/2026 00:00:00  0022500612  20260119/MIAGSW
# 689                                        None
# 695                                        None
# 773                                        None
# 801                                        None
# 845                                        None
# 865                                        None
# 876                                        None
# 897                                        None
# 943                                        None
# 959                                        None
# 1020                                       None
# 1043                                       None
# 1137                                       None
# 1150                                       None
# 1190                                       None
# 1194                                       None
# 1219                                       None
# 1231                                       None
# 1247                                       None
#
#      awayOttBroadcasters_tapeDelayComments  \
# 9
# 19
# 69                                    None
# 86                                    None
# 122                                   None
# 128                                   None
# 178
# 216                                   None
# 305
# 329
# 340                                   None
# 359
# 384                                   None
# 460
# 475                                   None
# 493                                   None
# 557                                   None
# 565
# 599                                   None
# 612                                   None
# 629                                   None
# 643                                   None
# 657                                   None
# 672                                   None
# 689                                   None
# 695                                   None
# 773                                   None
# 801                                   None
# 845                                   None
# 865                                   None
# 876                                   None
# 897                                   None
# 943                                   None
# 959                                   None
# 1020                                  None
# 1043                                  None
# 1137                                  None
# 1150                                  None
# 1190                                  None
# 1194                                  None
# 1219                                  None
# 1231                                  None
# 1247                                  None
#
#      awayOttBroadcasters_broadcasterVideoLink  \
# 9
# 19
# 69                                       None
# 86                                       None
# 122                                      None
# 128                                      None
# 178
# 216                                      None
# 305
# 329
# 340                                      None
# 359
# 384                                      None
# 460
# 475                                      None
# 493                                      None
# 557                                      None
# 565
# 599                                      None
# 612                                      None
# 629                                      None
# 643                                      None
# 657                                      None
# 672                                      None
# 689                                      None
# 695                                      None
# 773                                      None
# 801                                      None
# 845                                      None
# 865                                      None
# 876                                      None
# 897                                      None
# 943                                      None
# 959                                      None
# 1020                                     None
# 1043                                     None
# 1137                                     None
# 1150                                     None
# 1190                                     None
# 1194                                     None
# 1219                                     None
# 1231                                     None
# 1247                                     None
#
#       awayOttBroadcasters_broadcasterTeamId  \
# 9                              1.610613e+09
# 19                             1.610613e+09
# 69                                      NaN
# 86                                      NaN
# 122                                     NaN
# 128                                     NaN
# 178                            1.610613e+09
# 216                                     NaN
# 305                            1.610613e+09
# 329                            1.610613e+09
# 340                                     NaN
# 359                            1.610613e+09
# 384                                     NaN
# 460                            1.610613e+09
# 475                                     NaN
# 493                                     NaN
# 557                                     NaN
# 565                            1.610613e+09
# 599                                     NaN
# 612                                     NaN
# 629                                     NaN
# 643                                     NaN
# 657                                     NaN
# 672                                     NaN
# 689                                     NaN
# 695                                     NaN
# 773                                     NaN
# 801                                     NaN
# 845                                     NaN
# 865                                     NaN
# 876                                     NaN
# 897                                     NaN
# 943                                     NaN
# 959                                     NaN
# 1020                                    NaN
# 1043                                    NaN
# 1137                                    NaN
# 1150                                    NaN
# 1190                                    NaN
# 1194                                    NaN
# 1219                                    NaN
# 1231                                    NaN
# 1247                                    NaN
#
#       awayOttBroadcasters_broadcasterRanking  \
# 9                                       None
# 19                                      None
# 69                                      None
# 86                                      None
# 122                                     None
# 128                                     None
# 178                                     None
# 216                                     None
# 305                                     None
# 329                                     None
# 340                                     None
# 359                                     None
# 384                                     None
# 460                                     None
# 475                                     None
# 493                                     None
# 557                                     None
# 565                                     None
# 599                                     None
# 612                                     None
# 629                                     None
# 643                                     None
# 657                                     None
# 672                                     None
# 689                                     None
# 695                                     None
# 773                                     None
# 801                                     None
# 845                                     None
# 865                                     None
# 876                                     None
# 897                                     None
# 943                                     None
# 959                                     None
# 1020                                    None
# 1043                                    None
# 1137                                    None
# 1150                                    None
# 1190                                    None
# 1194                                    None
# 1219                                    None
# 1231                                    None
# 1247                                    None
#
#      awayOttBroadcasters_localizationRegion
# 9
# 19
# 69                                     None
# 86                                     None
# 122                                    None
# 128                                    None
# 178
# 216                                    None
# 305
# 329
# 340                                    None
# 359
# 384                                    None
# 460
# 475                                    None
# 493                                    None
# 557                                    None
# 565
# 599                                    None
# 612                                    None
# 629                                    None
# 643                                    None
# 657                                    None
# 672                                    None
# 689                                    None
# 695                                    None
# 773                                    None
# 801                                    None
# 845                                    None
# 865                                    None
# 876                                    None
# 897                                    None
# 943                                    None
# 959                                    None
# 1020                                   None
# 1043                                   None
# 1137                                   None
# 1150                                   None
# 1190                                   None
# 1194                                   None
# 1219                                   None
# 1231                                   None
# 1247                                   None
#
# [43 rows x 173 columns]

# %%
schedule_day.columns.tolist()
# Out:
# ['leagueId',
#  'seasonYear',
#  'gameDate',
#  'gameId',
#  'gameCode',
#  'gameStatus',
#  'gameStatusText',
#  'gameSequence',
#  'gameDateEst',
#  'gameTimeEst',
#  'gameDateTimeEst',
#  'gameDateUTC',
#  'gameTimeUTC',
#  'gameDateTimeUTC',
#  'awayTeamTime',
#  'homeTeamTime',
#  'day',
#  'monthNum',
#  'weekNumber',
#  'weekName',
#  'ifNecessary',
#  'seriesGameNumber',
#  'gameLabel',
#  'gameSubLabel',
#  'seriesText',
#  'arenaName',
#  'arenaState',
#  'arenaCity',
#  'postponedStatus',
#  'branchLink',
#  'gameSubtype',
#  'isNeutral',
#  'homeTeam_teamId',
#  'homeTeam_teamName',
#  'homeTeam_teamCity',
#  'homeTeam_teamTricode',
#  'homeTeam_teamSlug',
#  'homeTeam_wins',
#  'homeTeam_losses',
#  'homeTeam_score',
#  'homeTeam_seed',
#  'awayTeam_teamId',
#  'awayTeam_teamName',
#  'awayTeam_teamCity',
#  'awayTeam_teamTricode',
#  'awayTeam_teamSlug',
#  'awayTeam_wins',
#  'awayTeam_losses',
#  'awayTeam_score',
#  'awayTeam_seed',
#  'pointsLeaders_0_personId',
#  'pointsLeaders_0_firstName',
#  'pointsLeaders_0_lastName',
#  'pointsLeaders_0_teamId',
#  'pointsLeaders_0_teamCity',
#  'pointsLeaders_0_teamName',
#  'pointsLeaders_0_teamTricode',
#  'pointsLeaders_0_points',
#  'pointsLeaders_1_personId',
#  'pointsLeaders_1_firstName',
#  'pointsLeaders_1_lastName',
#  'pointsLeaders_1_teamId',
#  'pointsLeaders_1_teamCity',
#  'pointsLeaders_1_teamName',
#  'pointsLeaders_1_teamTricode',
#  'pointsLeaders_1_points',
#  'pointsLeaders_2_personId',
#  'pointsLeaders_2_firstName',
#  'pointsLeaders_2_lastName',
#  'pointsLeaders_2_teamId',
#  'pointsLeaders_2_teamCity',
#  'pointsLeaders_2_teamName',
#  'pointsLeaders_2_teamTricode',
#  'pointsLeaders_2_points',
#  'nationalBroadcasters_0_broadcasterScope',
#  'nationalBroadcasters_0_broadcasterMedia',
#  'nationalBroadcasters_0_broadcasterId',
#  'nationalBroadcasters_0_broadcasterDisplay',
#  'nationalBroadcasters_0_broadcasterAbbreviation',
#  'nationalBroadcasters_0_broadcasterDescription',
#  'nationalBroadcasters_0_tapeDelayComments',
#  'nationalBroadcasters_0_broadcasterVideoLink',
#  'nationalBroadcasters_0_broadcasterTeamId',
#  'nationalBroadcasters_0_broadcasterRanking',
#  'nationalBroadcasters_0_localizationRegion',
#  'nationalBroadcasters_1_broadcasterScope',
#  'nationalBroadcasters_1_broadcasterMedia',
#  'nationalBroadcasters_1_broadcasterId',
#  'nationalBroadcasters_1_broadcasterDisplay',
#  'nationalBroadcasters_1_broadcasterAbbreviation',
#  'nationalBroadcasters_1_broadcasterDescription',
#  'nationalBroadcasters_1_tapeDelayComments',
#  'nationalBroadcasters_1_broadcasterVideoLink',
#  'nationalBroadcasters_1_broadcasterTeamId',
#  'nationalBroadcasters_1_broadcasterRanking',
#  'nationalBroadcasters_1_localizationRegion',
#  'nationalRadioBroadcasters_broadcasterScope',
#  'nationalRadioBroadcasters_broadcasterMedia',
#  'nationalRadioBroadcasters_broadcasterId',
#  'nationalRadioBroadcasters_broadcasterDisplay',
#  'nationalRadioBroadcasters_broadcasterAbbreviation',
#  'nationalRadioBroadcasters_broadcasterDescription',
#  'nationalRadioBroadcasters_tapeDelayComments',
#  'nationalRadioBroadcasters_broadcasterVideoLink',
#  'nationalRadioBroadcasters_broadcasterTeamId',
#  'nationalRadioBroadcasters_broadcasterRanking',
#  'nationalRadioBroadcasters_localizationRegion',
#  'homeTvBroadcasters_broadcasterScope',
#  'homeTvBroadcasters_broadcasterMedia',
#  'homeTvBroadcasters_broadcasterId',
#  'homeTvBroadcasters_broadcasterDisplay',
#  'homeTvBroadcasters_broadcasterAbbreviation',
#  'homeTvBroadcasters_broadcasterDescription',
#  'homeTvBroadcasters_tapeDelayComments',
#  'homeTvBroadcasters_broadcasterVideoLink',
#  'homeTvBroadcasters_broadcasterTeamId',
#  'homeTvBroadcasters_broadcasterRanking',
#  'homeTvBroadcasters_localizationRegion',
#  'homeRadioBroadcasters_broadcasterScope',
#  'homeRadioBroadcasters_broadcasterMedia',
#  'homeRadioBroadcasters_broadcasterId',
#  'homeRadioBroadcasters_broadcasterDisplay',
#  'homeRadioBroadcasters_broadcasterAbbreviation',
#  'homeRadioBroadcasters_broadcasterDescription',
#  'homeRadioBroadcasters_tapeDelayComments',
#  'homeRadioBroadcasters_broadcasterVideoLink',
#  'homeRadioBroadcasters_broadcasterTeamId',
#  'homeRadioBroadcasters_broadcasterRanking',
#  'homeRadioBroadcasters_localizationRegion',
#  'homeOttBroadcasters_broadcasterScope',
#  'homeOttBroadcasters_broadcasterMedia',
#  'homeOttBroadcasters_broadcasterId',
#  'homeOttBroadcasters_broadcasterDisplay',
#  'homeOttBroadcasters_broadcasterAbbreviation',
#  'homeOttBroadcasters_broadcasterDescription',
#  'homeOttBroadcasters_tapeDelayComments',
#  'homeOttBroadcasters_broadcasterVideoLink',
#  'homeOttBroadcasters_broadcasterTeamId',
#  'homeOttBroadcasters_broadcasterRanking',
#  'homeOttBroadcasters_localizationRegion',
#  'awayTvBroadcasters_broadcasterScope',
#  'awayTvBroadcasters_broadcasterMedia',
#  'awayTvBroadcasters_broadcasterId',
#  'awayTvBroadcasters_broadcasterDisplay',
#  'awayTvBroadcasters_broadcasterAbbreviation',
#  'awayTvBroadcasters_broadcasterDescription',
#  'awayTvBroadcasters_tapeDelayComments',
#  'awayTvBroadcasters_broadcasterVideoLink',
#  'awayTvBroadcasters_broadcasterTeamId',
#  'awayTvBroadcasters_broadcasterRanking',
#  'awayTvBroadcasters_localizationRegion',
#  'awayRadioBroadcasters_broadcasterScope',
#  'awayRadioBroadcasters_broadcasterMedia',
#  'awayRadioBroadcasters_broadcasterId',
#  'awayRadioBroadcasters_broadcasterDisplay',
#  'awayRadioBroadcasters_broadcasterAbbreviation',
#  'awayRadioBroadcasters_broadcasterDescription',
#  'awayRadioBroadcasters_tapeDelayComments',
#  'awayRadioBroadcasters_broadcasterVideoLink',
#  'awayRadioBroadcasters_broadcasterTeamId',
#  'awayRadioBroadcasters_broadcasterRanking',
#  'awayRadioBroadcasters_localizationRegion',
#  'awayOttBroadcasters_broadcasterScope',
#  'awayOttBroadcasters_broadcasterMedia',
#  'awayOttBroadcasters_broadcasterId',
#  'awayOttBroadcasters_broadcasterDisplay',
#  'awayOttBroadcasters_broadcasterAbbreviation',
#  'awayOttBroadcasters_broadcasterDescription',
#  'awayOttBroadcasters_tapeDelayComments',
#  'awayOttBroadcasters_broadcasterVideoLink',
#  'awayOttBroadcasters_broadcasterTeamId',
#  'awayOttBroadcasters_broadcasterRanking',
#  'awayOttBroadcasters_localizationRegion']

# %%
select_columns = ['gameDate', 'gameId','gameStatus','gameStatusText','gameDateTimeUTC','homeTeam_teamName',
                      'homeTeam_score', 'awayTeam_teamName','awayTeam_score']

# %%
df = schedule_day[select_columns]

# %%
df['gameTimeUTC_plus3'] = pd.to_datetime(df['gameDateTimeUTC'], utc=True) + pd.Timedelta(hours=3)
# Out:
# /tmp/ipykernel_812433/768074370.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gameTimeUTC_plus3'] = pd.to_datetime(df['gameDateTimeUTC'], utc=True) + pd.Timedelta(hours=3)

# %%
df
# Out:
#                gameDate      gameId  gameStatus gameStatusText  \
# 73  10/22/2025 00:00:00  0022500003           1     7:00 pm ET
# 74  10/22/2025 00:00:00  0022500004           1     9:30 pm ET
# 75  10/22/2025 00:00:00  0022500080           1     7:00 pm ET
# 76  10/22/2025 00:00:00  0022500081           1     7:00 pm ET
# 77  10/22/2025 00:00:00  0022500082           1     7:30 pm ET
# 78  10/22/2025 00:00:00  0022500083           1     7:30 pm ET
# 79  10/22/2025 00:00:00  0022500084           1     8:00 pm ET
# 80  10/22/2025 00:00:00  0022500085           1     8:00 pm ET
# 81  10/22/2025 00:00:00  0022500086           1     8:00 pm ET
# 82  10/22/2025 00:00:00  0022500087           1     9:00 pm ET
# 83  10/22/2025 00:00:00  0022500088           1    10:00 pm ET
# 84  10/22/2025 00:00:00  0022500089           1    10:00 pm ET
#
#          gameDateTimeUTC homeTeam_teamName  homeTeam_score awayTeam_teamName  \
# 73  2025-10-22T23:00:00Z            Knicks               0         Cavaliers
# 74  2025-10-23T01:30:00Z         Mavericks               0             Spurs
# 75  2025-10-22T23:00:00Z           Hornets               0              Nets
# 76  2025-10-22T23:00:00Z             Magic               0              Heat
# 77  2025-10-22T23:30:00Z             Hawks               0           Raptors
# 78  2025-10-22T23:30:00Z           Celtics               0             76ers
# 79  2025-10-23T00:00:00Z             Bulls               0           Pistons
# 80  2025-10-23T00:00:00Z         Grizzlies               0          Pelicans
# 81  2025-10-23T00:00:00Z             Bucks               0           Wizards
# 82  2025-10-23T01:00:00Z              Jazz               0          Clippers
# 83  2025-10-23T02:00:00Z              Suns               0             Kings
# 84  2025-10-23T02:00:00Z     Trail Blazers               0      Timberwolves
#
#     awayTeam_score         gameTimeUTC_plus3
# 73               0 2025-10-23 02:00:00+00:00
# 74               0 2025-10-23 04:30:00+00:00
# 75               0 2025-10-23 02:00:00+00:00
# 76               0 2025-10-23 02:00:00+00:00
# 77               0 2025-10-23 02:30:00+00:00
# 78               0 2025-10-23 02:30:00+00:00
# 79               0 2025-10-23 03:00:00+00:00
# 80               0 2025-10-23 03:00:00+00:00
# 81               0 2025-10-23 03:00:00+00:00
# 82               0 2025-10-23 04:00:00+00:00
# 83               0 2025-10-23 05:00:00+00:00
# 84               0 2025-10-23 05:00:00+00:00

# %%
df.insert(5, 'estimate_end_time_UTC', pd.to_datetime(df['gameDateTimeUTC'], utc=True) + pd.Timedelta(hours=3))
df
# Out:
#                gameDate      gameId  gameStatus gameStatusText  \
# 73  10/22/2025 00:00:00  0022500003           1     7:00 pm ET
# 74  10/22/2025 00:00:00  0022500004           1     9:30 pm ET
# 75  10/22/2025 00:00:00  0022500080           1     7:00 pm ET
# 76  10/22/2025 00:00:00  0022500081           1     7:00 pm ET
# 77  10/22/2025 00:00:00  0022500082           1     7:30 pm ET
# 78  10/22/2025 00:00:00  0022500083           1     7:30 pm ET
# 79  10/22/2025 00:00:00  0022500084           1     8:00 pm ET
# 80  10/22/2025 00:00:00  0022500085           1     8:00 pm ET
# 81  10/22/2025 00:00:00  0022500086           1     8:00 pm ET
# 82  10/22/2025 00:00:00  0022500087           1     9:00 pm ET
# 83  10/22/2025 00:00:00  0022500088           1    10:00 pm ET
# 84  10/22/2025 00:00:00  0022500089           1    10:00 pm ET
#
#          gameDateTimeUTC     estimate_end_time_UTC homeTeam_teamName  \
# 73  2025-10-22T23:00:00Z 2025-10-23 02:00:00+00:00            Knicks
# 74  2025-10-23T01:30:00Z 2025-10-23 04:30:00+00:00         Mavericks
# 75  2025-10-22T23:00:00Z 2025-10-23 02:00:00+00:00           Hornets
# 76  2025-10-22T23:00:00Z 2025-10-23 02:00:00+00:00             Magic
# 77  2025-10-22T23:30:00Z 2025-10-23 02:30:00+00:00             Hawks
# 78  2025-10-22T23:30:00Z 2025-10-23 02:30:00+00:00           Celtics
# 79  2025-10-23T00:00:00Z 2025-10-23 03:00:00+00:00             Bulls
# 80  2025-10-23T00:00:00Z 2025-10-23 03:00:00+00:00         Grizzlies
# 81  2025-10-23T00:00:00Z 2025-10-23 03:00:00+00:00             Bucks
# 82  2025-10-23T01:00:00Z 2025-10-23 04:00:00+00:00              Jazz
# 83  2025-10-23T02:00:00Z 2025-10-23 05:00:00+00:00              Suns
# 84  2025-10-23T02:00:00Z 2025-10-23 05:00:00+00:00     Trail Blazers
#
#        estimate_end_time_utc  homeTeam_score awayTeam_teamName  \
# 73 2025-10-23 02:00:00+00:00               0         Cavaliers
# 74 2025-10-23 04:30:00+00:00               0             Spurs
# 75 2025-10-23 02:00:00+00:00               0              Nets
# 76 2025-10-23 02:00:00+00:00               0              Heat
# 77 2025-10-23 02:30:00+00:00               0           Raptors
# 78 2025-10-23 02:30:00+00:00               0             76ers
# 79 2025-10-23 03:00:00+00:00               0           Pistons
# 80 2025-10-23 03:00:00+00:00               0          Pelicans
# 81 2025-10-23 03:00:00+00:00               0           Wizards
# 82 2025-10-23 04:00:00+00:00               0          Clippers
# 83 2025-10-23 05:00:00+00:00               0             Kings
# 84 2025-10-23 05:00:00+00:00               0      Timberwolves
#
#     awayTeam_score         gameTimeUTC_plus3
# 73               0 2025-10-23 02:00:00+00:00
# 74               0 2025-10-23 04:30:00+00:00
# 75               0 2025-10-23 02:00:00+00:00
# 76               0 2025-10-23 02:00:00+00:00
# 77               0 2025-10-23 02:30:00+00:00
# 78               0 2025-10-23 02:30:00+00:00
# 79               0 2025-10-23 03:00:00+00:00
# 80               0 2025-10-23 03:00:00+00:00
# 81               0 2025-10-23 03:00:00+00:00
# 82               0 2025-10-23 04:00:00+00:00
# 83               0 2025-10-23 05:00:00+00:00
# 84               0 2025-10-23 05:00:00+00:00

# %%
pbp = playbyplayv3.PlayByPlayV3('0022500001')

# %%
pbp = pbp.get_data_frames()[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_812433/1893009333.py in ?()
# ----> 1 pbp = pbp.get_data_frames()[0]
#
# ~/.pyenv/versions/3.12.9/envs/lewagon_current/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_data_frames'

# %%
pbp.head()
# Out:
#    videoAvailable
# 0               1

# %%
games
# Out:
# [{'gameId': '0022500001',
#   'gameCode': '20251021/HOUOKC',
#   'gameStatus': 3,
#   'gameStatusText': 'Final/OT2',
#   'period': 6,
#   'gameClock': '',
#   'gameTimeUTC': '2025-10-21T23:30:00Z',
#   'gameEt': '2025-10-21T19:30:00Z',
#   'regulationPeriods': 4,
#   'ifNecessary': False,
#   'seriesGameNumber': '',
#   'gameLabel': '',
#   'gameSubLabel': '',
#   'seriesText': '',
#   'seriesConference': '',
#   'poRoundDesc': '',
#   'gameSubtype': '',
#   'isNeutral': False,
#   'homeTeam': {'teamId': 1610612760,
#    'teamName': 'Thunder',
#    'teamCity': 'Oklahoma City',
#    'teamTricode': 'OKC',
#    'wins': 1,
#    'losses': 0,
#    'score': 125,
#    'seed': None,
#    'inBonus': None,
#    'timeoutsRemaining': 0,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 27},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 24},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 24},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 29},
#     {'period': 5, 'periodType': 'OVERTIME', 'score': 11},
#     {'period': 6, 'periodType': 'OVERTIME', 'score': 10}]},
#   'awayTeam': {'teamId': 1610612745,
#    'teamName': 'Rockets',
#    'teamCity': 'Houston',
#    'teamTricode': 'HOU',
#    'wins': 0,
#    'losses': 1,
#    'score': 124,
#    'seed': None,
#    'inBonus': None,
#    'timeoutsRemaining': 0,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 30},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 27},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 22},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 25},
#     {'period': 5, 'periodType': 'OVERTIME', 'score': 11},
#     {'period': 6, 'periodType': 'OVERTIME', 'score': 9}]},
#   'gameLeaders': {'homeLeaders': {'personId': 1628983,
#     'name': 'Shai Gilgeous-Alexander',
#     'jerseyNum': '2',
#     'position': 'G',
#     'teamTricode': 'OKC',
#     'playerSlug': None,
#     'points': 35,
#     'rebounds': 5,
#     'assists': 5},
#    'awayLeaders': {'personId': 1630578,
#     'name': 'Alperen Sengun',
#     'jerseyNum': '28',
#     'position': 'C',
#     'teamTricode': 'HOU',
#     'playerSlug': None,
#     'points': 39,
#     'rebounds': 11,
#     'assists': 7}},
#   'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#  {'gameId': '0022500002',
#   'gameCode': '20251021/GSWLAL',
#   'gameStatus': 3,
#   'gameStatusText': 'Final',
#   'period': 4,
#   'gameClock': '',
#   'gameTimeUTC': '2025-10-22T02:00:00Z',
#   'gameEt': '2025-10-21T22:00:00Z',
#   'regulationPeriods': 4,
#   'ifNecessary': False,
#   'seriesGameNumber': '',
#   'gameLabel': '',
#   'gameSubLabel': '',
#   'seriesText': '',
#   'seriesConference': '',
#   'poRoundDesc': '',
#   'gameSubtype': '',
#   'isNeutral': False,
#   'homeTeam': {'teamId': 1610612747,
#    'teamName': 'Lakers',
#    'teamCity': 'Los Angeles',
#    'teamTricode': 'LAL',
#    'wins': 0,
#    'losses': 1,
#    'score': 109,
#    'seed': None,
#    'inBonus': None,
#    'timeoutsRemaining': 0,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 22},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 32},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 25},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 30}]},
#   'awayTeam': {'teamId': 1610612744,
#    'teamName': 'Warriors',
#    'teamCity': 'Golden State',
#    'teamTricode': 'GSW',
#    'wins': 1,
#    'losses': 0,
#    'score': 119,
#    'seed': None,
#    'inBonus': None,
#    'timeoutsRemaining': 0,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 28},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 27},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 35},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 29}]},
#   'gameLeaders': {'homeLeaders': {'personId': 1629029,
#     'name': 'Luka DonÄ\x8diÄ\x87',
#     'jerseyNum': '77',
#     'position': 'F-G',
#     'teamTricode': 'LAL',
#     'playerSlug': None,
#     'points': 43,
#     'rebounds': 12,
#     'assists': 9},
#    'awayLeaders': {'personId': 202710,
#     'name': 'Jimmy Butler III',
#     'jerseyNum': '10',
#     'position': 'F',
#     'teamTricode': 'GSW',
#     'playerSlug': None,
#     'points': 31,
#     'rebounds': 5,
#     'assists': 4}},
#   'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}}]

# %%
len(games)
# Out:
# 2

# %%
df = pd.DataFrame.from_dict(games[0],orient='columns')
df
# Out:
#                        gameId         gameCode  gameStatus gameStatusText  \
# teamId             0022500001  20251021/HOUOKC           3      Final/OT2
# teamName           0022500001  20251021/HOUOKC           3      Final/OT2
# teamCity           0022500001  20251021/HOUOKC           3      Final/OT2
# teamTricode        0022500001  20251021/HOUOKC           3      Final/OT2
# wins               0022500001  20251021/HOUOKC           3      Final/OT2
# losses             0022500001  20251021/HOUOKC           3      Final/OT2
# score              0022500001  20251021/HOUOKC           3      Final/OT2
# seed               0022500001  20251021/HOUOKC           3      Final/OT2
# inBonus            0022500001  20251021/HOUOKC           3      Final/OT2
# timeoutsRemaining  0022500001  20251021/HOUOKC           3      Final/OT2
# periods            0022500001  20251021/HOUOKC           3      Final/OT2
# homeLeaders        0022500001  20251021/HOUOKC           3      Final/OT2
# awayLeaders        0022500001  20251021/HOUOKC           3      Final/OT2
# team               0022500001  20251021/HOUOKC           3      Final/OT2
# odds               0022500001  20251021/HOUOKC           3      Final/OT2
# suspended          0022500001  20251021/HOUOKC           3      Final/OT2
#
#                    period gameClock           gameTimeUTC  \
# teamId                  6            2025-10-21T23:30:00Z
# teamName                6            2025-10-21T23:30:00Z
# teamCity                6            2025-10-21T23:30:00Z
# teamTricode             6            2025-10-21T23:30:00Z
# wins                    6            2025-10-21T23:30:00Z
# losses                  6            2025-10-21T23:30:00Z
# score                   6            2025-10-21T23:30:00Z
# seed                    6            2025-10-21T23:30:00Z
# inBonus                 6            2025-10-21T23:30:00Z
# timeoutsRemaining       6            2025-10-21T23:30:00Z
# periods                 6            2025-10-21T23:30:00Z
# homeLeaders             6            2025-10-21T23:30:00Z
# awayLeaders             6            2025-10-21T23:30:00Z
# team                    6            2025-10-21T23:30:00Z
# odds                    6            2025-10-21T23:30:00Z
# suspended               6            2025-10-21T23:30:00Z
#
#                                  gameEt  regulationPeriods  ifNecessary  ...  \
# teamId             2025-10-21T19:30:00Z                  4        False  ...
# teamName           2025-10-21T19:30:00Z                  4        False  ...
# teamCity           2025-10-21T19:30:00Z                  4        False  ...
# teamTricode        2025-10-21T19:30:00Z                  4        False  ...
# wins               2025-10-21T19:30:00Z                  4        False  ...
# losses             2025-10-21T19:30:00Z                  4        False  ...
# score              2025-10-21T19:30:00Z                  4        False  ...
# seed               2025-10-21T19:30:00Z                  4        False  ...
# inBonus            2025-10-21T19:30:00Z                  4        False  ...
# timeoutsRemaining  2025-10-21T19:30:00Z                  4        False  ...
# periods            2025-10-21T19:30:00Z                  4        False  ...
# homeLeaders        2025-10-21T19:30:00Z                  4        False  ...
# awayLeaders        2025-10-21T19:30:00Z                  4        False  ...
# team               2025-10-21T19:30:00Z                  4        False  ...
# odds               2025-10-21T19:30:00Z                  4        False  ...
# suspended          2025-10-21T19:30:00Z                  4        False  ...
#
#                   gameSubLabel seriesText seriesConference poRoundDesc  \
# teamId
# teamName
# teamCity
# teamTricode
# wins
# losses
# score
# seed
# inBonus
# timeoutsRemaining
# periods
# homeLeaders
# awayLeaders
# team
# odds
# suspended
#
#                   gameSubtype isNeutral  \
# teamId                            False
# teamName                          False
# teamCity                          False
# teamTricode                       False
# wins                              False
# losses                            False
# score                             False
# seed                              False
# inBonus                           False
# timeoutsRemaining                 False
# periods                           False
# homeLeaders                       False
# awayLeaders                       False
# team                              False
# odds                              False
# suspended                         False
#
#                                                             homeTeam  \
# teamId                                                    1610612760
# teamName                                                     Thunder
# teamCity                                               Oklahoma City
# teamTricode                                                      OKC
# wins                                                               1
# losses                                                             0
# score                                                            125
# seed                                                            None
# inBonus                                                         None
# timeoutsRemaining                                                  0
# periods            [{'period': 1, 'periodType': 'REGULAR', 'score...
# homeLeaders                                                      NaN
# awayLeaders                                                      NaN
# team                                                             NaN
# odds                                                             NaN
# suspended                                                        NaN
#
#                                                             awayTeam  \
# teamId                                                    1610612745
# teamName                                                     Rockets
# teamCity                                                     Houston
# teamTricode                                                      HOU
# wins                                                               0
# losses                                                             1
# score                                                            124
# seed                                                            None
# inBonus                                                         None
# timeoutsRemaining                                                  0
# periods            [{'period': 1, 'periodType': 'REGULAR', 'score...
# homeLeaders                                                      NaN
# awayLeaders                                                      NaN
# team                                                             NaN
# odds                                                             NaN
# suspended                                                        NaN
#
#                                                          gameLeaders pbOdds
# teamId                                                           NaN    NaN
# teamName                                                         NaN    NaN
# teamCity                                                         NaN    NaN
# teamTricode                                                      NaN    NaN
# wins                                                             NaN    NaN
# losses                                                           NaN    NaN
# score                                                            NaN    NaN
# seed                                                             NaN    NaN
# inBonus                                                          NaN    NaN
# timeoutsRemaining                                                NaN    NaN
# periods                                                          NaN    NaN
# homeLeaders        {'personId': 1628983, 'name': 'Shai Gilgeous-A...    NaN
# awayLeaders        {'personId': 1630578, 'name': 'Alperen Sengun'...    NaN
# team                                                             NaN    NaN
# odds                                                             NaN    0.0
# suspended                                                        NaN    0.0
#
# [16 rows x 22 columns]

# %%
all_games = pd.DataFrame()

for i in range(len(games)):
    df = pd.DataFrame.from_dict(games[i],orient='columns')
    
    game_date = df['gameTimeUTC'].iloc[0][:10]
    gameId = df['gameId'].iloc[0]
    gameStatusText = df['gameStatusText'].iloc[0]
    
    df = df[['homeTeam','awayTeam']][:7]
    df= df.T
    
    df.insert(loc=0, column='game_date', value=game_date)
    df.insert(loc=1, column='game_id', value=gameId)
    df.insert(loc=2, column='game_status', value=gameStatusText)
    
    all_games = pd.concat([all_games,df])

# %%
all_games
# Out:
#            game_date     game_id game_status      teamId  teamName  \
# homeTeam  2025-10-21  0022500001   Final/OT2  1610612760   Thunder
# awayTeam  2025-10-21  0022500001   Final/OT2  1610612745   Rockets
# homeTeam  2025-10-22  0022500002       Final  1610612747    Lakers
# awayTeam  2025-10-22  0022500002       Final  1610612744  Warriors
#
#                teamCity teamTricode wins losses score
# homeTeam  Oklahoma City         OKC    1      0   125
# awayTeam        Houston         HOU    0      1   124
# homeTeam    Los Angeles         LAL    0      1   109
# awayTeam   Golden State         GSW    1      0   119
